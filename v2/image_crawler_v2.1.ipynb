# %%
import os
import time
import random
import hashlib
from icrawler.builtin import GoogleImageCrawler

TARGET_IMAGES = 200
ADD_BREAD_SUFFIX = True
base_dir = "raw_images_crawled"

def read_keywords(file_path):
    with open(file_path, "r", encoding="utf-8") as f:
        return [line.strip() for line in f if line.strip()]

def hash_image_bytes(file_path):
    try:
        with open(file_path, "rb") as f:
            return hashlib.md5(f.read()).hexdigest()
    except Exception:
        return None

def get_existing_hashes(folder):
    if not os.path.exists(folder):
        return set()
    return set(filter(None, [
        hash_image_bytes(os.path.join(folder, f))
        for f in os.listdir(folder)
        if f.lower().endswith(('.jpg', '.jpeg', '.png', '.webp', '.gif'))
    ]))

def simple_crawl(keyword, save_dir, target_count):
    existing_hashes = get_existing_hashes(save_dir)
    start_count = len(existing_hashes)
    print(f"🗂️  Existing images: {start_count}")

    crawler = GoogleImageCrawler(storage={'root_dir': save_dir})
    crawler.crawl(
        keyword=keyword,
        max_num=target_count + 50  # 약간 여유롭게 받아서 중복 제거 후 수량 확보
    )

    # 중복 제거: 다운로드 후 다시 체크
    all_files = [
        f for f in os.listdir(save_dir)
        if f.lower().endswith(('.jpg', '.jpeg', '.png', '.webp', '.gif'))
    ]
    new_hashes = {}
    for f in all_files:
        path = os.path.join(save_dir, f)
        h = hash_image_bytes(path)
        if h in existing_hashes or h in new_hashes:
            os.remove(path)
        else:
            new_hashes[h] = f

    total = len(existing_hashes) + len(new_hashes)
    return total

# --- MAIN ---

bread_types = read_keywords("keywords.txt")
os.makedirs(base_dir, exist_ok=True)

for bread in bread_types:
    safe_name = bread.replace(" ", "_").replace("/", "_")
    image_dir = os.path.join(base_dir, safe_name, "images")
    os.makedirs(image_dir, exist_ok=True)

    print(f"▶ Processing: {bread}")
    keyword = f"{bread} bread" if ADD_BREAD_SUFFIX else bread
    total_images = simple_crawl(keyword, image_dir, TARGET_IMAGES)

    print(f"✅ Finished '{bread}' - Total images now: {total_images}")

    if bread != bread_types[-1]:
        time.sleep(random.uniform(3, 6))

print("\n🎉 All crawling completed successfully.")
# Out:
# 2025-06-06 13:03:56,631 - INFO - icrawler.crawler - start crawling...
# 2025-06-06 13:03:56,631 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2025-06-06 13:03:56,632 - INFO - feeder - thread feeder-001 exit
# 2025-06-06 13:03:56,633 - INFO - icrawler.crawler - starting 1 parser threads...
# 2025-06-06 13:03:56,634 - INFO - icrawler.crawler - starting 1 downloader threads...
# ▶ Processing: 크루아상
# 🗂️  Existing images: 0
# 2025-06-06 13:03:57,722 - INFO - parser - parsing result page https://www.google.com/search?q=%ED%81%AC%EB%A3%A8%EC%95%84%EC%83%81+bread&ijn=0&start=0&tbs=&tbm=isch
# 2025-06-06 13:03:57,907 - INFO - downloader - image #1	https://m.tlj.co.kr/data/product/2018-7-26_event(2).jpg
# 2025-06-06 13:03:58,039 - INFO - downloader - image #2	https://dapa-magazine.kr/page/vol104/img/sub10_02.jpg
# 2025-06-06 13:03:58,062 - INFO - downloader - image #3	https://m.tlj.co.kr/data/product/2024-9-30_event(29).jpg
# 2025-06-06 13:03:58,332 - INFO - downloader - image #4	https://cdn.crowdpic.net/detail-thumb/thumb_d_383929E031C622ECDA1EEDB79BFA5CFD.jpg
# 2025-06-06 13:03:58,459 - INFO - downloader - image #5	https://oasisprodproduct.edge.naverncp.com/56051/detail/detail_56051_0_7be457fb-46cc-4fe3-ab88-b5e149643111.jpg
# 2025-06-06 13:03:58,662 - INFO - downloader - image #6	https://cdn.crowdpic.net/detail-thumb/thumb_d_A9F1600561935A2248AD4B5BBEC524D6.jpg
# 2025-06-06 13:03:58,810 - INFO - downloader - image #7	https://shop.hansalim.or.kr/shopping/is/itm/080417003/080417003_1_568.jpg
# 2025-06-06 13:03:59,064 - INFO - downloader - image #8	https://recipe1.ezmember.co.kr/cache/recipe/2020/10/02/4de62923a224ac34446019b523b9ae661.jpg
# 2025-06-06 13:03:59,176 - INFO - downloader - image #9	https://m.goodsesang.com/web/product/big/202504/6bceaa0b79233d974bc1298927238789.jpg
# 2025-06-06 13:03:59,236 - INFO - downloader - image #10	http://imagescdn.gettyimagesbank.com/500/201402/a7348196.jpg
# 2025-06-06 13:03:59,396 - INFO - downloader - image #11	https://cdn.crowdpic.net/detail-thumb/thumb_d_4A1052FFE5428A15B88CA14B8947D7E6.jpg
# 2025-06-06 13:04:00,982 - INFO - downloader - image #12	https://upload.wikimedia.org/wikipedia/commons/c/c1/APileOfCroissants.jpg
# 2025-06-06 13:04:01,017 - ERROR - downloader - Exception caught when downloading file https://png, error: HTTPSConnectionPool(host='png', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x114272c10>: Failed to resolve 'png' ([Errno 8] nodename nor servname provided, or not known)")), remaining retry times: 2
# 2025-06-06 13:04:01,023 - ERROR - downloader - Exception caught when downloading file https://png, error: HTTPSConnectionPool(host='png', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x114273110>: Failed to resolve 'png' ([Errno 8] nodename nor servname provided, or not known)")), remaining retry times: 1
# 2025-06-06 13:04:01,028 - ERROR - downloader - Exception caught when downloading file https://png, error: HTTPSConnectionPool(host='png', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x1142734d0>: Failed to resolve 'png' ([Errno 8] nodename nor servname provided, or not known)")), remaining retry times: 0
# 2025-06-06 13:04:01,046 - ERROR - downloader - Exception caught when downloading file https://kor.png, error: HTTPSConnectionPool(host='kor.png', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x114273890>: Failed to resolve 'kor.png' ([Errno 8] nodename nor servname provided, or not known)")), remaining retry times: 2
# 2025-06-06 13:04:01,050 - ERROR - downloader - Exception caught when downloading file https://kor.png, error: HTTPSConnectionPool(host='kor.png', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x114273d90>: Failed to resolve 'kor.png' ([Errno 8] nodename nor servname provided, or not known)")), remaining retry times: 1
# 2025-06-06 13:04:01,055 - ERROR - downloader - Exception caught when downloading file https://kor.png, error: HTTPSConnectionPool(host='kor.png', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x133d80190>: Failed to resolve 'kor.png' ([Errno 8] nodename nor servname provided, or not known)")), remaining retry times: 0
# 2025-06-06 13:04:02,581 - INFO - downloader - image #13	https://n-object.com/web/product/big/202212/49faae8880810eec5d32e0615632b4cf.jpg
# 2025-06-06 13:04:02,735 - INFO - downloader - image #14	https://bumkok.com/wp-content/uploads/2025/04/%EC%82%AC%EC%9B%8C%EB%8F%84%EC%9A%B0-%ED%81%AC%EB%A3%A8%EC%95%84%EC%83%81INNER.png
# 2025-06-06 13:04:03,588 - ERROR - downloader - Response status code 404, file https://p.turbosquid.com/ts-thumb/v9/LSybnm/kC/productshots_01/png
# 2025-06-06 13:04:03,708 - INFO - downloader - image #15	https://shop.hansalim.or.kr/im/is/activeDesigner/080417003_content1.jpg
# 2025-06-06 13:04:03,796 - ERROR - downloader - Exception caught when downloading file https://semie.cooking/image/contents/recipe/ok/xj/hwtapysm/IRD/147024269yfxh.jpg, error: HTTPSConnectionPool(host='semie.cooking', port=443): Max retries exceeded with url: /image/contents/recipe/ok/xj/hwtapysm/IRD/147024269yfxh.jpg (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1028)'))), remaining retry times: 2
# 2025-06-06 13:04:03,829 - ERROR - downloader - Exception caught when downloading file https://semie.cooking/image/contents/recipe/ok/xj/hwtapysm/IRD/147024269yfxh.jpg, error: HTTPSConnectionPool(host='semie.cooking', port=443): Max retries exceeded with url: /image/contents/recipe/ok/xj/hwtapysm/IRD/147024269yfxh.jpg (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1028)'))), remaining retry times: 1
# 2025-06-06 13:04:03,857 - ERROR - downloader - Exception caught when downloading file https://semie.cooking/image/contents/recipe/ok/xj/hwtapysm/IRD/147024269yfxh.jpg, error: HTTPSConnectionPool(host='semie.cooking', port=443): Max retries exceeded with url: /image/contents/recipe/ok/xj/hwtapysm/IRD/147024269yfxh.jpg (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1028)'))), remaining retry times: 0
# 2025-06-06 13:04:03,927 - INFO - downloader - image #16	https://img-cf.kurly.com/hdims/resize/%3E720x/quality/90/src/shop/data/goodsview/20191115/gv20000068291_1.jpg
# 2025-06-06 13:04:04,005 - INFO - downloader - image #17	https://www.dessertco.co.kr/data/item/1691459980/thumb-7IaM6riI_500x500.jpg
# 2025-06-06 13:04:04,267 - INFO - downloader - image #18	https://recipe1.ezmember.co.kr/cache/recipe/2022/04/04/5b0c6c239556c1a57b2dd324380f56991.jpg
# 2025-06-06 13:04:04,428 - INFO - downloader - image #19	https://blog.kakaocdn.net/dn/Lsedv/btsdxiT903z/ItMWGRqqpZN55l9VuwKiJ1/img.jpg
# 2025-06-06 13:04:04,814 - INFO - downloader - image #20	https://i.ytimg.com/vi/rfC2HTOsUBk/hq720.jpg
# 2025-06-06 13:04:04,922 - INFO - downloader - image #21	http://www.shinsegaefood.com/uimages/2023/02/08/01.jpg
# 2025-06-06 13:04:07,078 - INFO - downloader - image #22	https://img.freepik.com/premium-photo/croissant-bread-white-plate-lies-white-table_532332-2897.jpg
# 2025-06-06 13:04:07,181 - INFO - downloader - image #23	https://img1.daumcdn.net/thumb/R800x0/?scode=mtistory2&fname=https%3A%2F%2Fblog.kakaocdn.net%2Fdn%2Fmo9Xc%2FbtsIklmCRj6%2F9ClbYKPWzGVijnMKsLBKoK%2Fimg.jpg
# 2025-06-06 13:04:08,506 - INFO - downloader - image #24	https://static.wtable.co.kr/image/production/service/recipe/2069/02970dde-8744-4cfc-9904-a73db4bc032f.jpg
# 2025-06-06 13:04:08,654 - INFO - downloader - image #25	https://oasisprodproduct.edge.naverncp.com/56051/detail/detail_56051_2_3eceebb1-b11e-4a74-80d0-177e939f0e23.jpg
# 2025-06-06 13:04:08,882 - INFO - downloader - image #26	https://doodoo22.openhost.cafe24.com/1koollook/vic1f/22_23_1/63c6890803424.jpg
# 2025-06-06 13:04:08,984 - INFO - downloader - image #27	https://img.daily.co.kr/@files/www.daily.co.kr/content/food/2024/20241126/9b24d4f5d8a05cce93f1ae57835d7eca.jpg
# 2025-06-06 13:04:10,066 - INFO - downloader - image #28	https://image2.lotteimall.com/goods/48/19/90/1576901948_1.jpg
# 2025-06-06 13:04:11,095 - INFO - downloader - image #29	https://sc04.alicdn.com/kf/Had6ed94d88894c4ca26027e79ef066e0X.jpg
# 2025-06-06 13:04:11,564 - ERROR - downloader - Response status code 404, file https://img.lovepik.com/png
# 2025-06-06 13:04:11,673 - INFO - downloader - image #30	https://m.woori-ga.com/web/product/big/202203/e420fd6bb619aebbafbd8a98aadf0bcc.jpg
# 2025-06-06 13:04:11,773 - INFO - downloader - image #31	https://bumkok.com/wp-content/uploads/2025/04/%ED%81%AC%EB%A3%A8%EC%95%84%EC%83%81-INNER-optimized.png
# 2025-06-06 13:04:11,836 - ERROR - downloader - Response status code 404, file https://mblogthumb-phinf.pstatic.net/MjAxNzAzMTlfMTAx/MDAxNDg5OTEwNDA2NDc2.O-IhiAKg3TEDR7nreaaw77zlJoNFnSCR7wJ81hkdmeMg.quuknxmFaCCQVFB18ZZyAZBa76HglXMarUGnM27c0_Ug.JPEG.noteasygirl/se3_image_266085725.jpg
# 2025-06-06 13:04:12,790 - INFO - downloader - image #32	https://giridang.com/wp-content/uploads/2024/03/sc.jpg
# 2025-06-06 13:04:12,879 - INFO - downloader - image #33	https://d2afncas1tel3t.cloudfront.net/wp-content/uploads/2024/10/%EC%9A%B0%EC%9C%A0%ED%81%AC%EB%A6%BC%EC%8D%B8%EB%84%AC-1-600x600.jpg
# 2025-06-06 13:04:12,976 - INFO - downloader - image #34	https://static.wtable.co.kr/image/production/service/recipe/1788/8a6c5d47-ffd9-4e8c-b661-0bc25a0a7941.jpg
# 2025-06-06 13:04:13,077 - INFO - downloader - image #35	https://cafe24img.poxo.com/maniland/web/product/big/202409/b21ffddd6b8c8dbc7b95ae8464aec776.jpg
# 2025-06-06 13:04:13,618 - INFO - downloader - image #36	https://blog.kakaocdn.net/dn/cbp4XB/btshHMDmSEk/ykqv8EzZrdQDEWoXIJdpRk/img.png
# 2025-06-06 13:04:14,981 - INFO - downloader - image #37	https://previews.123rf.com/images/tananu9/tananu92107/tananu9210700046/172074430-%ED%81%AC%EB%A3%A8%EC%95%84%EC%83%81-%EB%B9%B5-%EC%95%84%EC%B9%A8-%EC%8B%9D%EC%82%AC-%EB%8B%A4%EC%9D%B4%EC%96%B4%ED%8A%B8-%EB%9D%BC%EC%9D%B4%ED%94%84%EC%8A%A4%ED%83%80%EC%9D%BC-%EC%BB%A8%EC%85%89%EC%9D%98-%EB%82%99%EC%84%9C-%ED%94%84%EB%A6%AC%ED%95%B8%EB%93%9C-%EC%8A%A4%EC%BC%80%EC%B9%98-%EA%B7%B8%EB%A6%AC%EA%B8%B0.jpg
# 2025-06-06 13:04:15,390 - INFO - downloader - image #38	https://i.ytimg.com/vi/ufNVGbydqSk/hq720.jpg
# 2025-06-06 13:04:15,485 - INFO - downloader - image #39	https://blog.kakaocdn.net/dn/puzmA/btsH0ka4X4U/Z6wcHuQhqaaWiqGL1v3KEK/img.jpg
# 2025-06-06 13:04:15,832 - INFO - downloader - image #40	https://www.spcmagazine.com/wp-content/uploads/2024/11/Instagram-post-22-1.png
# 2025-06-06 13:04:15,933 - INFO - downloader - image #41	https://img.hankyung.com/photo/202407/01.37251945.1.jpg
# 2025-06-06 13:04:16,537 - INFO - downloader - image #42	https://goldenbrown.co.kr/uploaded/shop_good/307/76c5eb93b9b81ffe195958fb76e760750.jpg
# 2025-06-06 13:04:16,620 - INFO - downloader - image #43	https://cdn.crowdpic.net/detail-thumb/thumb_d_50CB1F85EBD4D604711DFB3B16D631FA.jpg
# 2025-06-06 13:04:16,766 - INFO - downloader - image #44	http://image.hnsmall.com/images/goods/392/27404392_g.jpg
# 2025-06-06 13:04:16,858 - INFO - downloader - image #45	https://cdn.pixabay.com/photo/2019/03/24/14/23/bread-4077812_640.jpg
# 2025-06-06 13:04:17,026 - INFO - downloader - image #46	https://img.wkorea.com/w/2024/01/style_65ae31f9b376f-1920x1080.jpg
# 2025-06-06 13:04:17,321 - INFO - downloader - image #47	https://recipe1.ezmember.co.kr/cache/recipe/2023/02/08/9bab1625e39d23cd49baa9865d6533cf1.jpg
# 2025-06-06 13:04:17,416 - INFO - downloader - image #48	https://m.goldcandy.co.kr/web/product/big/202009/56acda9c8be17c7304ab02a7f8f316c9.jpg
# 2025-06-06 13:04:18,699 - INFO - downloader - image #49	https://previews.123rf.com/images/stockyimages/stockyimages1508/stockyimages150800272/44277793-%ED%99%A9%EA%B8%88-%ED%81%AC%EB%A3%A8%EC%95%84%EC%83%81-%EB%B9%B5%EC%9D%98-%EC%9D%B4%EB%AF%B8%EC%A7%80%EB%A5%BC-%EB%8B%AB%EC%8A%B5%EB%8B%88%EB%8B%A4.jpg
# 2025-06-06 13:04:18,860 - INFO - downloader - image #50	https://pds.joongang.co.kr/news/component/htmlphoto_mmdata/202111/06/0d85c3d7-c61d-45a0-93da-03b852f8c396.jpg
# 2025-06-06 13:04:18,895 - ERROR - downloader - Exception caught when downloading file https://semie.cooking/image/contents/recipe/ok/xj/hwtapysm/IRD/147024274cmnl.jpg, error: HTTPSConnectionPool(host='semie.cooking', port=443): Max retries exceeded with url: /image/contents/recipe/ok/xj/hwtapysm/IRD/147024274cmnl.jpg (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1028)'))), remaining retry times: 2
# 2025-06-06 13:04:18,928 - ERROR - downloader - Exception caught when downloading file https://semie.cooking/image/contents/recipe/ok/xj/hwtapysm/IRD/147024274cmnl.jpg, error: HTTPSConnectionPool(host='semie.cooking', port=443): Max retries exceeded with url: /image/contents/recipe/ok/xj/hwtapysm/IRD/147024274cmnl.jpg (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1028)'))), remaining retry times: 1
# 2025-06-06 13:04:18,960 - ERROR - downloader - Exception caught when downloading file https://semie.cooking/image/contents/recipe/ok/xj/hwtapysm/IRD/147024274cmnl.jpg, error: HTTPSConnectionPool(host='semie.cooking', port=443): Max retries exceeded with url: /image/contents/recipe/ok/xj/hwtapysm/IRD/147024274cmnl.jpg (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1028)'))), remaining retry times: 0
# 2025-06-06 13:04:19,240 - INFO - downloader - image #51	https://cdn.polinews.co.kr/news/photo/202407/656775_462819_5027.jpg
# 2025-06-06 13:04:19,423 - INFO - downloader - image #52	https://gi.esmplus.com/doowonfns/06/1187/06_1187_02.jpg
# 2025-06-06 13:04:19,500 - INFO - downloader - image #53	http://imagescdn.gettyimagesbank.com/500/202009/a12094616.jpg
# 2025-06-06 13:04:19,691 - ERROR - downloader - Response status code 400, file https://media.istockphoto.com/id/1160746954/ko/%EB%B2%A1%ED%84%B0/%EB%A7%8C%ED%99%94-%EB%B9%B5-%EA%B0%80%EB%A3%A8%EC%99%80-%ED%8C%A8%EC%8A%A4%ED%8A%B8%EB%A6%AC-%ED%94%84%EB%A0%8C%EC%B9%98-%EB%B0%94%EA%B2%8C%ED%8A%B8-%EB%B0%8F-%EC%A1%B0%EC%8B%9D-%ED%81%AC%EB%A3%A8%EC%95%84%EC%83%81-%EB%B2%A0%EC%9D%B4%EC%BB%A4%EB%A6%AC-%EC%8A%A4%EB%82%B5-%EC%B4%88%EC%BD%9C%EB%A6%BF-%EC%BC%80%EC%9D%B4%ED%81%AC-%ED%8E%98%EC%9D%B4%EC%8A%A4%ED%8A%B8%EB%A6%AC-%ED%94%84%EB%A0%88%EC%B2%BC-%EB%B9%B5-%EB%B9%B5-%EB%B9%B5-%EB%B9%B5-%EC%8A%AC%EB%9D%BC%EC%9D%B4%EC%8A%A4-%EB%B9%B5.jpg
# 2025-06-06 13:04:19,904 - INFO - downloader - image #54	https://www.whitepaper.co.kr/news/photo/201507/44481_23199_4217.png
# 2025-06-06 13:04:20,046 - INFO - downloader - image #55	https://image.kmib.co.kr/online_image/2024/0910/2024091006165580490_1725916615_0020510076.png
# 2025-06-06 13:04:20,128 - INFO - downloader - image #56	https://www.dessertco.co.kr/data/item/1691459390/thumb-4S6A7123_500x500.jpg
# 2025-06-06 13:04:20,193 - INFO - downloader - image #57	https://ecimg.cafe24img.com/pg299b34409484036/baekih1001/web/product/medium/20240412/e381834ac794b4fda517f54254c34e15.jpg
# 2025-06-06 13:04:20,577 - INFO - downloader - image #58	https://cdn.thereport.co.kr/news/photo/202410/55014_65038_522.jpg
# 2025-06-06 13:04:20,946 - INFO - downloader - image #59	https://www.shutterstock.com/image-photo/croissant-bread-isolated-on-white-260nw-1300271113.jpg
# 2025-06-06 13:04:21,309 - INFO - downloader - image #60	https://cdn.imweb.me/upload/S20210927e14f9f0cf71bc/f08696de43809.jpg
# 2025-06-06 13:04:21,841 - INFO - downloader - image #61	https://i.ytimg.com/vi/oi9eRdiACHE/maxresdefault.jpg
# 2025-06-06 13:04:22,041 - INFO - parser - parsing result page https://www.google.com/search?q=%ED%81%AC%EB%A3%A8%EC%95%84%EC%83%81+bread&ijn=1&start=100&tbs=&tbm=isch
# Exception in thread parser-001:
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/threading.py", line 1041, in _bootstrap_inner
#     self.run()
#     ~~~~~~~~^^
#   File "/Users/hong/Desktop/25-1/AI intro/AI project/Image-Crawler/.venv/lib/python3.13/site-packages/ipykernel/ipkernel.py", line 766, in run_closure
#     _threading_Thread_run(self)
#     ~~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "/opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/threading.py", line 992, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/hong/Desktop/25-1/AI intro/AI project/Image-Crawler/.venv/lib/python3.13/site-packages/icrawler/parser.py", line 93, in worker_exec
#     for task in self.parse(response, **kwargs):
#                 ~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
# 2025-06-06 13:04:23,415 - INFO - downloader - image #62	https://img.freepik.com/premium-vector/croissant-bread-icon-hand-drawn-vector-illustration_755164-3880.jpg
# 2025-06-06 13:04:23,747 - INFO - downloader - image #63	https://www.spcmagazine.com/wp-content/uploads/2024/11/5.png
# 2025-06-06 13:04:24,008 - ERROR - downloader - Response status code 404, file https://img.lovepik.com/original_origin_pic/18/09/12/c3eaa636007be8d58d465f8fc19b6567.png
# 2025-06-06 13:04:24,113 - INFO - downloader - image #64	https://m.koreatimessquare.com/web/product/big/202406/05054f68a08315ece993a2bff5a35b4a.jpg
# 2025-06-06 13:04:24,201 - INFO - downloader - image #65	https://img-cf.kurly.com/hdims/resize/%3E720x/quality/90/src/shop/data/goodsview/20230718/gv30000711724_1.jpg
# 2025-06-06 13:04:29,207 - INFO - downloader - no more download task for thread downloader-001
# 2025-06-06 13:04:29,208 - INFO - downloader - thread downloader-001 exit
# 2025-06-06 13:04:29,752 - INFO - icrawler.crawler - Crawling task done!
# ✅ Finished '크루아상' - Total images now: 65
# 2025-06-06 13:04:35,100 - INFO - icrawler.crawler - start crawling...
# 2025-06-06 13:04:35,101 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2025-06-06 13:04:35,102 - INFO - feeder - thread feeder-001 exit
# 2025-06-06 13:04:35,102 - INFO - icrawler.crawler - starting 1 parser threads...
# 2025-06-06 13:04:35,104 - INFO - icrawler.crawler - starting 1 downloader threads...
# ▶ Processing: 크로와상
# 🗂️  Existing images: 0
# 2025-06-06 13:04:36,031 - INFO - parser - parsing result page https://www.google.com/search?q=%ED%81%AC%EB%A1%9C%EC%99%80%EC%83%81+bread&ijn=0&start=0&tbs=&tbm=isch
# 2025-06-06 13:04:36,210 - INFO - downloader - image #1	https://m.tlj.co.kr/data/product/2018-7-26_event(2).jpg
# 2025-06-06 13:04:37,020 - INFO - downloader - image #2	https://i.ytimg.com/vi/ptzC8dN8hEU/hq720.jpg
# 2025-06-06 13:04:37,060 - INFO - downloader - image #3	http://imagescdn.gettyimagesbank.com/500/201402/a7348196.jpg
# 2025-06-06 13:04:37,278 - INFO - downloader - image #4	https://thingotr4652.cdn-nhncommerce.com/data/goods/23/01/03/1000030707/register_detail_077.jpg
# 2025-06-06 13:04:37,340 - INFO - downloader - image #5	https://www.dessertco.co.kr/data/item/1691459980/thumb-7IaM6riI_500x500.jpg
# 2025-06-06 13:04:37,572 - INFO - downloader - image #6	https://cdn.crowdpic.net/detail-thumb/thumb_d_2D7B66DBDD6B16834B6E88A4C03316AE.jpg
# 2025-06-06 13:04:37,806 - INFO - downloader - image #7	https://cdn.crowdpic.net/detail-thumb/thumb_d_306FCD234771B709BEBADC1BB337D93E.jpg
# 2025-06-06 13:04:38,101 - INFO - downloader - image #8	https://recipe1.ezmember.co.kr/cache/recipe/2023/02/08/9bab1625e39d23cd49baa9865d6533cf1.jpg
# 2025-06-06 13:04:38,123 - INFO - downloader - image #9	https://m.tlj.co.kr/data/product/2024-9-30_event(29).jpg
# 2025-06-06 13:04:38,193 - INFO - downloader - image #10	https://recipe1.ezmember.co.kr/cache/recipe/2021/10/18/215a4fe8c1d0bf54b061bbd77616e8251.jpg
# 2025-06-06 13:04:38,335 - INFO - downloader - image #11	https://cdn.crowdpic.net/detail-thumb/thumb_d_E8C27CDFF156B0DE96608F7E1E08D227.jpg
# 2025-06-06 13:04:38,364 - INFO - downloader - image #12	https://www.dessertco.co.kr/data/item/1691459390/thumb-4S6A7123_500x500.jpg
# 2025-06-06 13:04:38,385 - INFO - downloader - image #13	https://cdn.crowdpic.net/detail-thumb/thumb_d_509758855645B86399C8E1116581854D.jpg
# 2025-06-06 13:04:38,677 - INFO - downloader - image #14	https://i.ytimg.com/vi/0VThznz1rL8/hqdefault.jpg
# 2025-06-06 13:04:38,790 - INFO - downloader - image #15	https://www.breadtour.co.kr/web/product/big/202306/09aaf579020d79b86e70f31f6cbc92f0.jpg
# 2025-06-06 13:04:38,918 - INFO - downloader - image #16	https://godomall.speedycdn.net/ec5d2a1c8483712efb957784c858b320/goods/1000006655/image/add3/1000006655_add3_057.jpg
# 2025-06-06 13:04:39,020 - INFO - downloader - image #17	https://image.idus.com/image/files/4503c209e87c4829b49020a7d9a01546_720.jpg
# 2025-06-06 13:04:39,029 - ERROR - downloader - Exception caught when downloading file https://png, error: HTTPSConnectionPool(host='png', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x114273390>: Failed to resolve 'png' ([Errno 8] nodename nor servname provided, or not known)")), remaining retry times: 2
# 2025-06-06 13:04:39,034 - ERROR - downloader - Exception caught when downloading file https://png, error: HTTPSConnectionPool(host='png', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x114272c10>: Failed to resolve 'png' ([Errno 8] nodename nor servname provided, or not known)")), remaining retry times: 1
# 2025-06-06 13:04:39,040 - ERROR - downloader - Exception caught when downloading file https://png, error: HTTPSConnectionPool(host='png', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x133f70190>: Failed to resolve 'png' ([Errno 8] nodename nor servname provided, or not known)")), remaining retry times: 0
# 2025-06-06 13:04:39,045 - ERROR - downloader - Exception caught when downloading file https://kor.png, error: HTTPSConnectionPool(host='kor.png', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x1142720d0>: Failed to resolve 'kor.png' ([Errno 8] nodename nor servname provided, or not known)")), remaining retry times: 2
# 2025-06-06 13:04:39,051 - ERROR - downloader - Exception caught when downloading file https://kor.png, error: HTTPSConnectionPool(host='kor.png', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x133f70910>: Failed to resolve 'kor.png' ([Errno 8] nodename nor servname provided, or not known)")), remaining retry times: 1
# 2025-06-06 13:04:39,056 - ERROR - downloader - Exception caught when downloading file https://kor.png, error: HTTPSConnectionPool(host='kor.png', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x133f70cd0>: Failed to resolve 'kor.png' ([Errno 8] nodename nor servname provided, or not known)")), remaining retry times: 0
# 2025-06-06 13:04:40,425 - INFO - downloader - image #18	https://contents.kyobobook.co.kr/sih/fit-in/400x0/gift/pdt/1688/hot1729488981357.jpg
# 2025-06-06 13:04:40,564 - INFO - downloader - image #19	https://m.iuniontree.com/web/product/medium/202504/11396133674f295f6373a6cca6babf24.jpg
# 2025-06-06 13:04:42,121 - INFO - downloader - image #20	https://upload.wikimedia.org/wikipedia/commons/c/c1/APileOfCroissants.jpg
# 2025-06-06 13:04:43,482 - INFO - downloader - image #21	https://previews.123rf.com/images/margouillat/margouillat1512/margouillat151200239/49474208-%EB%AA%A8%EB%93%AC-%EB%90%9C-%ED%81%AC%EB%A1%9C%EC%99%80%EC%83%81%EA%B3%BC-%EB%B9%B5.jpg
# 2025-06-06 13:04:43,557 - INFO - downloader - image #22	https://cdn.crowdpic.net/detail-thumb/thumb_d_241F2EABCD5E700272525A22DF0E525A.jpg
# 2025-06-06 13:04:44,044 - INFO - downloader - image #23	https://s.alicdn.com/@sc04/kf/Hb09f8120aff340918b4a00ce100be938D.jpg
# 2025-06-06 13:04:44,115 - INFO - downloader - image #24	https://cdn.pixabay.com/photo/2013/04/07/21/30/bread-101636_640.jpg
# 2025-06-06 13:04:44,576 - INFO - downloader - image #25	https://i.ytimg.com/vi/eCbypQ0S6H8/hq720.jpg
# 2025-06-06 13:04:48,903 - INFO - downloader - image #26	https://image2.lotteimall.com/goods/34/73/36/1544367334_1.jpg
# 2025-06-06 13:04:50,329 - INFO - downloader - image #27	https://previews.123rf.com/images/amaviael/amaviael1402/amaviael140200110/25904012-various-types-of-bread-like-french-croissants-italian-ciabatta-german-buns-and-other.jpg
# 2025-06-06 13:04:50,514 - INFO - downloader - image #28	https://cdn.crowdpic.net/detail-thumb/thumb_d_5AFF3E0D2921A7FE638EA02A6FBE6CE8.jpg
# 2025-06-06 13:04:50,592 - INFO - downloader - image #29	https://sitem.ssgcdn.com/70/97/11/item/1000025119770_i1_750.jpg
# 2025-06-06 13:04:50,691 - INFO - downloader - image #30	https://m.iuniontree.com/web/product/medium/202503/67b4f94dc32cf693edcdade4df744900.png
# 2025-06-06 13:04:54,059 - INFO - downloader - image #31	https://get.pxhere.com/photo/croissant-food-dish-cuisine-ingredient-bread-baked-goods-pigs-in-blankets-pastry-produce-appetizer-viennoiserie-bread-roll-dessert-danish-pastry-kifli-1620518.jpg
# 2025-06-06 13:04:54,638 - INFO - downloader - image #32	https://i.ytimg.com/vi/n1A6WkzIlbw/hq720.jpg
# 2025-06-06 13:04:54,723 - INFO - downloader - image #33	https://cdn.pixabay.com/photo/2023/01/24/16/23/bread-7741485_1280.jpg
# 2025-06-06 13:04:54,760 - INFO - downloader - image #34	https://sitem.ssgcdn.com/28/90/48/item/1000049489028_i1_750.jpg
# 2025-06-06 13:04:54,828 - ERROR - downloader - Response status code 404, file https://img.lovepik.com/png
# 2025-06-06 13:04:54,941 - INFO - downloader - image #35	https://img.danawa.com/prod_img/500000/547/691/img/12691547_1.jpg
# 2025-06-06 13:04:55,310 - ERROR - downloader - Response status code 404, file https://kr.pikbest.com/png
# 2025-06-06 13:04:56,640 - INFO - downloader - image #36	https://i.pinimg.com/736x/28/07/5d/28075db3c81a0c8b37494845af526aa5.jpg
# 2025-06-06 13:04:56,703 - ERROR - downloader - Response status code 404, file https://mblogthumb-phinf.pstatic.net/MjAyNDAxMTFfMjI0/MDAxNzA0OTY5MzA5Mjc0.WseVkfXBvfu1OVbgki-Ei3l7rj4FIsYPtwPRYfdknYMg.1-NWeoeqb2Yq1JyX8-JAddUdZPC-concEK55bE3N0EYg.JPEG.halim7401/20240110_224243.jpg
# 2025-06-06 13:04:57,949 - INFO - downloader - image #37	https://blog.kakaocdn.net/dn/bbV7lZ/btrpBCfIcu3/GIaovpiq2ZkO7S2elAIXG0/img.png
# 2025-06-06 13:04:58,310 - INFO - downloader - image #38	https://s.alicdn.com/@sc04/kf/H89fe7857a7e6425ebc8bb797f2e03676S.jpg
# 2025-06-06 13:04:58,510 - INFO - downloader - image #39	https://recipe1.ezmember.co.kr/cache/recipe/2021/12/28/83d668836438486938a40d34123fa18c1.jpg
# 2025-06-06 13:04:58,594 - ERROR - downloader - Response status code 403, file https://www.chosun.com/resizer/v2/KLI73EUVNBGUNAR4UE5RBVFVNU.png
# 2025-06-06 13:04:59,223 - INFO - downloader - image #40	https://blog.kakaocdn.net/dn/LBAZk/btsLTGujaiy/QAXudEtlJEMqOoURTg1LxK/img.jpg
# 2025-06-06 13:04:59,477 - INFO - downloader - image #41	https://contents.kyobobook.co.kr/sih/fit-in/400x0/gift/pdt/1084/hot1729488985052.jpg
# 2025-06-06 13:04:59,732 - INFO - downloader - image #42	https://thumbnail10.coupangcdn.com/thumbnails/remote/492x492ex/image/retail/images/30881383153097-453758db-ec4b-4a3e-8570-d83813113ba0.jpg
# 2025-06-06 13:05:02,526 - INFO - downloader - image #43	https://image.fnnews.com/resource/media/image/2022/04/14/202204141805294529_l.jpg
# 2025-06-06 13:05:02,609 - INFO - downloader - image #44	https://thumbnail9.coupangcdn.com/thumbnails/remote/492x492ex/image/retail/images/966228125109444-07e4b84d-9f45-45fa-ac6c-767e5c54a255.jpg
# 2025-06-06 13:05:02,691 - WARNING - urllib3.connection - Failed to parse headers (url=https://godomall.speedycdn.net:443/882b5df9715f2cf11bb5f345d6888688/goods/293/image/add3/293_add3_060.jpg): [NoBoundaryInMultipartDefect()], unparsed data: ''
# Traceback (most recent call last):
#   File "/Users/hong/Desktop/25-1/AI intro/AI project/Image-Crawler/.venv/lib/python3.13/site-packages/urllib3/connection.py", line 519, in getresponse
#     assert_header_parsing(httplib_response.msg)
#     ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/hong/Desktop/25-1/AI intro/AI project/Image-Crawler/.venv/lib/python3.13/site-packages/urllib3/util/response.py", line 88, in assert_header_parsing
#     raise HeaderParsingError(defects=defects, unparsed_data=unparsed_data)
# urllib3.exceptions.HeaderParsingError: [NoBoundaryInMultipartDefect()], unparsed data: ''
# 2025-06-06 13:05:02,788 - INFO - downloader - image #45	https://godomall.speedycdn.net/882b5df9715f2cf11bb5f345d6888688/goods/293/image/add3/293_add3_060.jpg
# 2025-06-06 13:05:02,952 - INFO - downloader - image #46	https://sc04.alicdn.com/kf/He31f88ff400d4c9e80e351a2b63a4592a.jpg
# 2025-06-06 13:05:03,080 - INFO - downloader - image #47	http://thumbnail.10x10.co.kr/webimage/image/basic600/542/B005426177.jpg
# 2025-06-06 13:05:03,125 - INFO - downloader - image #48	https://blog.kakaocdn.net/dn/F4vDD/btrNxfio1H3/rI3VMkM0zTGhcNgkiENzIK/img.jpg
# 2025-06-06 13:05:03,506 - INFO - downloader - image #49	https://cdn.crowdpic.net/detail-thumb/thumb_d_9B70A15C9D6F02258A139FE15C1EEC2F.png
# 2025-06-06 13:05:05,174 - INFO - downloader - image #50	https://img.freepik.com/premium-vector/cartoon-bread-flour-pastries-french-baguette-breakfast-croissant-bakery-snacks-chocolate-cake-pastry-pretzel-buns-loaf-rye-sliced-breads_81894-3576.jpg
# 2025-06-06 13:05:05,225 - ERROR - downloader - Response status code 404, file https://mblogthumb-phinf.pstatic.net/MjAyMjAyMDhfMTg4/MDAxNjQ0MzI4NzQwNjI3.L7Fs93l-f12zywf-bSYZlZWAPVA0DjErvQRzA3sjUnkg.xMfcK79RzXrS_0GILAUW2SQ68FTe2BAqCA36WYvfJX0g.PNG.rightyellowblue/SE-fb2d4ff1-70e5-470b-a9f8-792fe41ab470.png
# 2025-06-06 13:05:05,298 - INFO - downloader - image #51	https://cafe24.poxo.com/ec01/umon11067/65uN764GExGfUPmYExKJktN3T4KpwQZVFq6Ve4ygLIyvJhSz0xBmj2qudA2vgnVEVysbdotbfk40uO/DdsTfbA==/_/web/product/big/202307/41462f1190225172e6faf7ec167d4f02.jpg
# 2025-06-06 13:05:05,393 - INFO - downloader - image #52	https://m.itovic.com/web/product/big/202410/9c492887cd224b297962a3f750fe9b99.jpg
# 2025-06-06 13:05:06,992 - INFO - downloader - image #53	https://previews.123rf.com/images/mayrisio/mayrisio2006/mayrisio200600061/148344240-set-of-different-types-shapes-and-sizes-of-breads-and-homemade-baked-products-croissant-loaf-bun.jpg
# 2025-06-06 13:05:07,094 - INFO - downloader - image #54	https://byjeanne.com/web/product/big/201811/3775e06bd1547e79800c7288407515d2.jpg
# 2025-06-06 13:05:07,349 - ERROR - downloader - Response status code 400, file https://media.istockphoto.com/id/1478678251/ko/%EC%82%AC%EC%A7%84/%ED%81%AC%EB%A1%9C%EC%99%80%EC%83%81%EC%9D%80-%EB%B2%84%ED%84%B0%EA%B0%80-%EC%84%9E%EC%9D%B8-%EB%94%94%EC%A0%80%ED%8A%B8%EC%9E%85%EB%8B%88%EB%8B%A4-%EB%98%90%EB%8A%94-%EC%B4%88%EC%8A%B9%EB%8B%AC-%EB%AA%A8%EC%96%91%EC%9D%98-%EB%B9%B5%EC%9C%BC%EB%A1%9C-%EB%8D%94-%EC%9E%98-%EC%95%8C%EB%A0%A4%EC%A0%B8-%EC%9E%88%EC%8A%B5%EB%8B%88%EB%8B%A4.jpg
# 2025-06-06 13:05:07,769 - INFO - downloader - image #55	https://i.ytimg.com/vi/VOpWvf_oAGI/maxresdefault.jpg
# 2025-06-06 13:05:08,269 - INFO - downloader - image #56	https://cdn.011st.com/11dims/resize/2000x2000/quality/75/11src/product/5470686651/B.jpg
# 2025-06-06 13:05:08,419 - INFO - downloader - image #57	https://godomall.speedycdn.net/2fd2b2779a329c7554a00bd0cf62b823/goods/1000001651/image/detail/1000001651_detail_035.png
# 2025-06-06 13:05:08,517 - INFO - downloader - image #58	https://m.ohpackege.com/web/product/big/202105/d3d210046185ca93c7964546ccf874cf.jpg
# 2025-06-06 13:05:08,578 - INFO - downloader - image #59	https://www.shutterstock.com/image-vector/food-collection-set-pizza-donut-260nw-2367964547.jpg
# 2025-06-06 13:05:08,691 - INFO - downloader - image #60	https://cafe24img.poxo.com/maniland/web/product/big/202409/b21ffddd6b8c8dbc7b95ae8464aec776.jpg
# 2025-06-06 13:05:09,019 - INFO - downloader - image #61	https://thumbnail8.coupangcdn.com/thumbnails/remote/492x492ex/image/retail/images/3048528512961313-f33e98ef-e2f3-4eca-a122-84400e242f35.jpg
# 2025-06-06 13:05:09,049 - WARNING - urllib3.connection - Failed to parse headers (url=https://godomall.speedycdn.net:443/d656187a6fa538c6aa56a9fb24ed4efa/goods/1000000615/image/main/1000000615_main_089.jpg): [NoBoundaryInMultipartDefect()], unparsed data: ''
# Traceback (most recent call last):
#   File "/Users/hong/Desktop/25-1/AI intro/AI project/Image-Crawler/.venv/lib/python3.13/site-packages/urllib3/connection.py", line 519, in getresponse
#     assert_header_parsing(httplib_response.msg)
#     ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/hong/Desktop/25-1/AI intro/AI project/Image-Crawler/.venv/lib/python3.13/site-packages/urllib3/util/response.py", line 88, in assert_header_parsing
#     raise HeaderParsingError(defects=defects, unparsed_data=unparsed_data)
# urllib3.exceptions.HeaderParsingError: [NoBoundaryInMultipartDefect()], unparsed data: ''
# 2025-06-06 13:05:09,076 - INFO - downloader - image #62	https://godomall.speedycdn.net/d656187a6fa538c6aa56a9fb24ed4efa/goods/1000000615/image/main/1000000615_main_089.jpg
# 2025-06-06 13:05:09,218 - INFO - parser - parsing result page https://www.google.com/search?q=%ED%81%AC%EB%A1%9C%EC%99%80%EC%83%81+bread&ijn=1&start=100&tbs=&tbm=isch
# Exception in thread parser-001:
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/threading.py", line 1041, in _bootstrap_inner
#     self.run()
#     ~~~~~~~~^^
#   File "/Users/hong/Desktop/25-1/AI intro/AI project/Image-Crawler/.venv/lib/python3.13/site-packages/ipykernel/ipkernel.py", line 766, in run_closure
#     _threading_Thread_run(self)
#     ~~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "/opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/threading.py", line 992, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/hong/Desktop/25-1/AI intro/AI project/Image-Crawler/.venv/lib/python3.13/site-packages/icrawler/parser.py", line 93, in worker_exec
#     for task in self.parse(response, **kwargs):
#                 ~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
# 2025-06-06 13:05:14,081 - INFO - downloader - no more download task for thread downloader-001
# 2025-06-06 13:05:14,082 - INFO - downloader - thread downloader-001 exit
# 2025-06-06 13:05:14,233 - INFO - icrawler.crawler - Crawling task done!
# ✅ Finished '크로와상' - Total images now: 62
# 2025-06-06 13:05:18,464 - INFO - icrawler.crawler - start crawling...
# 2025-06-06 13:05:18,464 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2025-06-06 13:05:18,465 - INFO - feeder - thread feeder-001 exit
# 2025-06-06 13:05:18,465 - INFO - icrawler.crawler - starting 1 parser threads...
# 2025-06-06 13:05:18,466 - INFO - icrawler.crawler - starting 1 downloader threads...
# ▶ Processing: 크루아상
# 🗂️  Existing images: 65
# 2025-06-06 13:05:19,399 - INFO - parser - parsing result page https://www.google.com/search?q=%ED%81%AC%EB%A3%A8%EC%95%84%EC%83%81+bread&ijn=0&start=0&tbs=&tbm=isch
# 2025-06-06 13:05:19,506 - INFO - downloader - skip downloading file 000001.jpg
# 2025-06-06 13:05:19,506 - INFO - downloader - skip downloading file 000002.jpg
# 2025-06-06 13:05:19,507 - INFO - downloader - skip downloading file 000003.jpg
# 2025-06-06 13:05:19,507 - INFO - downloader - skip downloading file 000004.jpg
# 2025-06-06 13:05:19,507 - INFO - downloader - skip downloading file 000005.jpg
# 2025-06-06 13:05:19,508 - INFO - downloader - skip downloading file 000006.jpg
# 2025-06-06 13:05:19,508 - INFO - downloader - skip downloading file 000007.jpg
# 2025-06-06 13:05:19,508 - INFO - downloader - skip downloading file 000008.jpg
# 2025-06-06 13:05:19,508 - INFO - downloader - skip downloading file 000009.jpg
# 2025-06-06 13:05:19,509 - INFO - downloader - skip downloading file 000010.jpg
# 2025-06-06 13:05:19,509 - INFO - downloader - skip downloading file 000011.jpg
# 2025-06-06 13:05:19,509 - INFO - downloader - skip downloading file 000012.jpg
# 2025-06-06 13:05:19,509 - INFO - downloader - skip downloading file 000013.jpg
# 2025-06-06 13:05:19,511 - ERROR - downloader - Exception caught when downloading file https://kor.png, error: HTTPSConnectionPool(host='kor.png', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x114273390>: Failed to resolve 'kor.png' ([Errno 8] nodename nor servname provided, or not known)")), remaining retry times: 2
# 2025-06-06 13:05:19,512 - ERROR - downloader - Exception caught when downloading file https://kor.png, error: HTTPSConnectionPool(host='kor.png', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x133f711d0>: Failed to resolve 'kor.png' ([Errno 8] nodename nor servname provided, or not known)")), remaining retry times: 1
# 2025-06-06 13:05:19,518 - ERROR - downloader - Exception caught when downloading file https://kor.png, error: HTTPSConnectionPool(host='kor.png', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x114273390>: Failed to resolve 'kor.png' ([Errno 8] nodename nor servname provided, or not known)")), remaining retry times: 0
# 2025-06-06 13:05:21,040 - INFO - downloader - image #14	https://n-object.com/web/product/big/202212/49faae8880810eec5d32e0615632b4cf.jpg
# 2025-06-06 13:05:21,142 - INFO - downloader - image #15	https://bumkok.com/wp-content/uploads/2025/04/%EC%82%AC%EC%9B%8C%EB%8F%84%EC%9A%B0-%ED%81%AC%EB%A3%A8%EC%95%84%EC%83%81INNER.png
# 2025-06-06 13:05:21,145 - INFO - downloader - skip downloading file 000016.jpg
# 2025-06-06 13:05:21,147 - INFO - downloader - skip downloading file 000017.jpg
# 2025-06-06 13:05:21,148 - INFO - downloader - skip downloading file 000018.jpg
# 2025-06-06 13:05:21,529 - INFO - downloader - skip downloading file 000019.jpg
# 2025-06-06 13:05:21,531 - INFO - downloader - skip downloading file 000020.jpg
# 2025-06-06 13:05:21,532 - INFO - downloader - skip downloading file 000021.jpg
# 2025-06-06 13:05:21,533 - INFO - downloader - skip downloading file 000022.jpg
# 2025-06-06 13:05:21,533 - INFO - downloader - skip downloading file 000023.jpg
# 2025-06-06 13:05:21,534 - INFO - downloader - skip downloading file 000024.jpg
# 2025-06-06 13:05:21,535 - INFO - downloader - skip downloading file 000025.jpg
# 2025-06-06 13:05:21,535 - INFO - downloader - skip downloading file 000026.jpg
# 2025-06-06 13:05:21,536 - INFO - downloader - skip downloading file 000027.jpg
# 2025-06-06 13:05:21,537 - INFO - downloader - skip downloading file 000028.jpg
# 2025-06-06 13:05:21,537 - INFO - downloader - skip downloading file 000029.jpg
# 2025-06-06 13:05:21,538 - INFO - downloader - skip downloading file 000030.jpg
# 2025-06-06 13:05:22,051 - INFO - downloader - image #31	https://doodoo22.openhost.cafe24.com/1koollook/vic1f/22_23_1/63c6890803424.jpg
# 2025-06-06 13:05:22,053 - INFO - downloader - skip downloading file 000032.jpg
# 2025-06-06 13:05:22,054 - INFO - downloader - skip downloading file 000033.jpg
# 2025-06-06 13:05:22,054 - INFO - downloader - skip downloading file 000034.jpg
# 2025-06-06 13:05:22,055 - INFO - downloader - skip downloading file 000035.jpg
# 2025-06-06 13:05:22,457 - INFO - downloader - image #36	https://sc04.alicdn.com/kf/Had6ed94d88894c4ca26027e79ef066e0X.jpg
# 2025-06-06 13:05:22,459 - INFO - downloader - skip downloading file 000037.jpg
# 2025-06-06 13:05:22,460 - INFO - downloader - skip downloading file 000038.jpg
# 2025-06-06 13:05:22,573 - INFO - downloader - image #39	https://bumkok.com/wp-content/uploads/2025/04/%ED%81%AC%EB%A3%A8%EC%95%84%EC%83%81-INNER-optimized.png
# 2025-06-06 13:05:22,745 - ERROR - downloader - Response status code 404, file https://mblogthumb-phinf.pstatic.net/MjAxNzAzMTlfMTAx/MDAxNDg5OTEwNDA2NDc2.O-IhiAKg3TEDR7nreaaw77zlJoNFnSCR7wJ81hkdmeMg.quuknxmFaCCQVFB18ZZyAZBa76HglXMarUGnM27c0_Ug.JPEG.noteasygirl/se3_image_266085725.jpg
# 2025-06-06 13:05:23,646 - INFO - downloader - image #40	https://giridang.com/wp-content/uploads/2024/03/sc.jpg
# 2025-06-06 13:05:23,649 - INFO - downloader - skip downloading file 000041.jpg
# 2025-06-06 13:05:23,650 - INFO - downloader - skip downloading file 000042.jpg
# 2025-06-06 13:05:23,650 - INFO - downloader - skip downloading file 000043.jpg
# 2025-06-06 13:05:23,651 - INFO - downloader - skip downloading file 000044.jpg
# 2025-06-06 13:05:23,826 - INFO - downloader - image #45	https://blog.kakaocdn.net/dn/cbp4XB/btshHMDmSEk/ykqv8EzZrdQDEWoXIJdpRk/img.png
# 2025-06-06 13:05:23,829 - INFO - downloader - skip downloading file 000046.jpg
# 2025-06-06 13:05:23,830 - INFO - downloader - skip downloading file 000047.jpg
# 2025-06-06 13:05:23,830 - INFO - downloader - skip downloading file 000048.jpg
# 2025-06-06 13:05:24,260 - INFO - downloader - image #49	https://www.spcmagazine.com/wp-content/uploads/2024/11/Instagram-post-22-1.png
# 2025-06-06 13:05:24,262 - INFO - downloader - skip downloading file 000050.jpg
# 2025-06-06 13:05:24,263 - INFO - downloader - skip downloading file 000051.jpg
# 2025-06-06 13:05:24,264 - INFO - downloader - skip downloading file 000052.jpg
# 2025-06-06 13:05:24,264 - INFO - downloader - skip downloading file 000053.jpg
# 2025-06-06 13:05:24,377 - INFO - downloader - image #54	http://image.hnsmall.com/images/goods/392/27404392_g.jpg
# 2025-06-06 13:05:24,471 - INFO - downloader - image #55	https://cdn.pixabay.com/photo/2019/03/24/14/23/bread-4077812_640.jpg
# 2025-06-06 13:05:24,473 - INFO - downloader - skip downloading file 000056.jpg
# 2025-06-06 13:05:24,475 - INFO - downloader - skip downloading file 000057.jpg
# 2025-06-06 13:05:24,476 - INFO - downloader - skip downloading file 000058.jpg
# 2025-06-06 13:05:24,478 - INFO - downloader - skip downloading file 000059.jpg
# 2025-06-06 13:05:24,479 - INFO - downloader - skip downloading file 000060.jpg
# 2025-06-06 13:05:24,480 - INFO - downloader - skip downloading file 000061.jpg
# 2025-06-06 13:05:24,481 - INFO - downloader - skip downloading file 000062.jpg
# 2025-06-06 13:05:24,611 - INFO - downloader - image #63	https://gi.esmplus.com/doowonfns/06/1187/06_1187_02.jpg
# 2025-06-06 13:05:24,613 - INFO - downloader - skip downloading file 000064.jpg
# 2025-06-06 13:05:24,614 - INFO - downloader - skip downloading file 000065.jpg
# 2025-06-06 13:05:25,110 - ERROR - downloader - Response status code 400, file https://media.istockphoto.com/id/1160746954/ko/%EB%B2%A1%ED%84%B0/%EB%A7%8C%ED%99%94-%EB%B9%B5-%EA%B0%80%EB%A3%A8%EC%99%80-%ED%8C%A8%EC%8A%A4%ED%8A%B8%EB%A6%AC-%ED%94%84%EB%A0%8C%EC%B9%98-%EB%B0%94%EA%B2%8C%ED%8A%B8-%EB%B0%8F-%EC%A1%B0%EC%8B%9D-%ED%81%AC%EB%A3%A8%EC%95%84%EC%83%81-%EB%B2%A0%EC%9D%B4%EC%BB%A4%EB%A6%AC-%EC%8A%A4%EB%82%B5-%EC%B4%88%EC%BD%9C%EB%A6%BF-%EC%BC%80%EC%9D%B4%ED%81%AC-%ED%8E%98%EC%9D%B4%EC%8A%A4%ED%8A%B8%EB%A6%AC-%ED%94%84%EB%A0%88%EC%B2%BC-%EB%B9%B5-%EB%B9%B5-%EB%B9%B5-%EB%B9%B5-%EC%8A%AC%EB%9D%BC%EC%9D%B4%EC%8A%A4-%EB%B9%B5.jpg
# 2025-06-06 13:05:25,267 - INFO - downloader - image #66	https://www.whitepaper.co.kr/news/photo/201507/44481_23199_4217.png
# 2025-06-06 13:05:25,394 - INFO - downloader - image #67	https://image.kmib.co.kr/online_image/2024/0910/2024091006165580490_1725916615_0020510076.png
# 2025-06-06 13:05:25,455 - INFO - downloader - image #68	https://www.dessertco.co.kr/data/item/1691459390/thumb-4S6A7123_500x500.jpg
# 2025-06-06 13:05:25,528 - INFO - downloader - image #69	https://ecimg.cafe24img.com/pg299b34409484036/baekih1001/web/product/medium/20240412/e381834ac794b4fda517f54254c34e15.jpg
# 2025-06-06 13:05:25,952 - INFO - downloader - image #70	https://cdn.thereport.co.kr/news/photo/202410/55014_65038_522.jpg
# 2025-06-06 13:05:26,040 - INFO - downloader - image #71	https://img-cf.kurly.com/hdims/resize/%3E720x/quality/90/src/shop/data/goodsview/20230718/gv30000711724_1.jpg
# 2025-06-06 13:05:26,215 - INFO - downloader - image #72	https://img.freepik.com/premium-vector/croissant-bread-icon-hand-drawn-vector-illustration_755164-3880.jpg
# 2025-06-06 13:05:26,502 - INFO - downloader - image #73	https://cdn.imweb.me/upload/S20210927e14f9f0cf71bc/f08696de43809.jpg
# 2025-06-06 13:05:26,565 - ERROR - downloader - Response status code 404, file https://img.lovepik.com/original_origin_pic/18/09/12/c3eaa636007be8d58d465f8fc19b6567.png
# 2025-06-06 13:05:26,866 - INFO - downloader - image #74	https://i.ytimg.com/vi/oi9eRdiACHE/maxresdefault.jpg
# 2025-06-06 13:05:27,010 - INFO - parser - parsing result page https://www.google.com/search?q=%ED%81%AC%EB%A3%A8%EC%95%84%EC%83%81+bread&ijn=1&start=100&tbs=&tbm=isch
# Exception in thread parser-001:
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/threading.py", line 1041, in _bootstrap_inner
#     self.run()
#     ~~~~~~~~^^
#   File "/Users/hong/Desktop/25-1/AI intro/AI project/Image-Crawler/.venv/lib/python3.13/site-packages/ipykernel/ipkernel.py", line 766, in run_closure
#     _threading_Thread_run(self)
#     ~~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "/opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/threading.py", line 992, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/hong/Desktop/25-1/AI intro/AI project/Image-Crawler/.venv/lib/python3.13/site-packages/icrawler/parser.py", line 93, in worker_exec
#     for task in self.parse(response, **kwargs):
#                 ~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
# 2025-06-06 13:05:27,317 - INFO - downloader - image #75	https://www.spcmagazine.com/wp-content/uploads/2024/11/5.png
# 2025-06-06 13:05:27,392 - INFO - downloader - image #76	https://m.koreatimessquare.com/web/product/big/202406/05054f68a08315ece993a2bff5a35b4a.jpg
# 2025-06-06 13:05:27,454 - INFO - downloader - image #77	https://m.woori-ga.com/web/product/big/202203/78052d135ded9e892120bde8ad5cbdf9.jpg
# 2025-06-06 13:05:32,461 - INFO - downloader - no more download task for thread downloader-001
# 2025-06-06 13:05:32,462 - INFO - downloader - thread downloader-001 exit
# 2025-06-06 13:05:32,508 - INFO - icrawler.crawler - Crawling task done!
# ✅ Finished '크루아상' - Total images now: 66
# 2025-06-06 13:05:38,574 - INFO - icrawler.crawler - start crawling...
# 2025-06-06 13:05:38,575 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2025-06-06 13:05:38,576 - INFO - feeder - thread feeder-001 exit
# 2025-06-06 13:05:38,576 - INFO - icrawler.crawler - starting 1 parser threads...
# 2025-06-06 13:05:38,578 - INFO - icrawler.crawler - starting 1 downloader threads...
# ▶ Processing: 크로아상
# 🗂️  Existing images: 0
# 2025-06-06 13:05:39,680 - INFO - parser - parsing result page https://www.google.com/search?q=%ED%81%AC%EB%A1%9C%EC%95%84%EC%83%81+bread&ijn=0&start=0&tbs=&tbm=isch
# 2025-06-06 13:05:39,855 - INFO - downloader - image #1	https://cdn.crowdpic.net/detail-thumb/thumb_d_383929E031C622ECDA1EEDB79BFA5CFD.jpg
# 2025-06-06 13:05:40,002 - INFO - downloader - image #2	https://cdn.crowdpic.net/detail-thumb/thumb_d_09475F3CEDA14856DDE305D342EF750F.jpg
# 2025-06-06 13:05:40,093 - INFO - downloader - image #3	https://m.goodsesang.com/web/product/big/202504/6bceaa0b79233d974bc1298927238789.jpg
# 2025-06-06 13:05:40,193 - INFO - downloader - image #4	https://blog.kakaocdn.net/dn/Lsedv/btsdxiT903z/ItMWGRqqpZN55l9VuwKiJ1/img.jpg
# 2025-06-06 13:05:40,361 - INFO - downloader - image #5	https://thingool123.godohosting.com/data/goods/20/10/42/1000015592/1000015592_detail_054.jpg
# 2025-06-06 13:05:40,408 - INFO - downloader - image #6	http://image.hnsmall.com/images/goods/424/21141424_g.jpg
# ...
# 2025-06-06 13:06:05,428 - INFO - parser - parsing result page https://www.google.com/search?q=%ED%81%AC%EB%A1%9C%EC%95%84%EC%83%81+bread&ijn=1&start=100&tbs=&tbm=isch
# Exception in thread parser-001:
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/threading.py", line 1041, in _bootstrap_inner
#     self.run()
#     ~~~~~~~~^^
#   File "/Users/hong/Desktop/25-1/AI intro/AI project/Image-Crawler/.venv/lib/python3.13/site-packages/ipykernel/ipkernel.py", line 766, in run_closure
#     _threading_Thread_run(self)
#     ~~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "/opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/threading.py", line 992, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/hong/Desktop/25-1/AI intro/AI project/Image-Crawler/.venv/lib/python3.13/site-packages/icrawler/parser.py", line 93, in worker_exec
#     for task in self.parse(response, **kwargs):
#                 ~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
# 2025-06-06 13:06:10,020 - INFO - downloader - no more download task for thread downloader-001
# 2025-06-06 13:06:10,021 - INFO - downloader - thread downloader-001 exit
# 2025-06-06 13:06:10,710 - INFO - icrawler.crawler - Crawling task done!
# ✅ Finished '크로아상' - Total images now: 63
# 2025-06-06 13:06:16,722 - INFO - icrawler.crawler - start crawling...
# 2025-06-06 13:06:16,723 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2025-06-06 13:06:16,723 - INFO - feeder - thread feeder-001 exit
# 2025-06-06 13:06:16,723 - INFO - icrawler.crawler - starting 1 parser threads...
# 2025-06-06 13:06:16,724 - INFO - icrawler.crawler - starting 1 downloader threads...
# ▶ Processing: croissant
# 🗂️  Existing images: 123
# 2025-06-06 13:06:17,747 - INFO - parser - parsing result page https://www.google.com/search?q=croissant+bread&ijn=0&start=0&tbs=&tbm=isch
# 2025-06-06 13:06:18,156 - INFO - downloader - image #1	https://sallysbakingaddiction.com/wp-content/uploads/2022/03/croissant-bread-3.jpg
# 2025-06-06 13:06:18,160 - INFO - downloader - skip downloading file 000002.jpg
# 2025-06-06 13:06:18,566 - INFO - downloader - image #3	https://thewoksoflife.com/wp-content/uploads/2021/12/milk-bread-croissants-34.jpg
# 2025-06-06 13:06:18,570 - INFO - downloader - skip downloading file 000004.jpg
# 2025-06-06 13:06:18,572 - INFO - downloader - skip downloading file 000005.jpg
# 2025-06-06 13:06:18,572 - INFO - downloader - skip downloading file 000006.jpg
# 2025-06-06 13:06:18,730 - INFO - downloader - image #7	https://breadsandsweets.com/wp-content/uploads/2021/08/croissant-pic-4.jpg
# 2025-06-06 13:06:18,733 - INFO - downloader - skip downloading file 000008.jpg
# 2025-06-06 13:06:18,734 - INFO - downloader - skip downloading file 000009.jpg
# 2025-06-06 13:06:20,333 - INFO - downloader - image #10	https://bakefromscratch.com/wp-content/uploads/2016/01/Croissant702SWSemail.jpg
# 2025-06-06 13:06:20,468 - INFO - downloader - image #11	https://baranbakery.com/wp-content/uploads/2024/07/Croissants-16-683x1024.jpg
# 2025-06-06 13:06:20,470 - INFO - downloader - skip downloading file 000012.jpg
# 2025-06-06 13:06:21,270 - INFO - downloader - image #13	https://www.halfbakedharvest.com/wp-content/uploads/2019/10/Easy-Swirled-Cinnamon-Sugar-Croissant-Loaf-1-1.jpg
# 2025-06-06 13:06:21,272 - INFO - downloader - skip downloading file 000014.jpg
# 2025-06-06 13:06:21,273 - INFO - downloader - skip downloading file 000015.jpg
# 2025-06-06 13:06:21,273 - INFO - downloader - skip downloading file 000016.jpg
# 2025-06-06 13:06:21,274 - INFO - downloader - skip downloading file 000017.jpg
# 2025-06-06 13:06:21,275 - INFO - downloader - skip downloading file 000018.jpg
# 2025-06-06 13:06:21,275 - INFO - downloader - skip downloading file 000019.jpg
# 2025-06-06 13:06:21,276 - INFO - downloader - skip downloading file 000020.jpg
# 2025-06-06 13:06:21,277 - INFO - downloader - skip downloading file 000021.jpg
# 2025-06-06 13:06:21,278 - INFO - downloader - skip downloading file 000022.jpg
# 2025-06-06 13:06:21,278 - INFO - downloader - skip downloading file 000023.jpg
# 2025-06-06 13:06:21,279 - INFO - downloader - skip downloading file 000024.jpg
# 2025-06-06 13:06:21,279 - INFO - downloader - skip downloading file 000025.jpg
# 2025-06-06 13:06:21,553 - INFO - downloader - image #26	https://saltpepperskillet.com/wp-content/uploads/croissant-bread-pudding-on-a-plate-close-up.jpg
# 2025-06-06 13:06:21,556 - INFO - downloader - skip downloading file 000027.jpg
# 2025-06-06 13:06:21,557 - INFO - downloader - skip downloading file 000028.jpg
# 2025-06-06 13:06:21,558 - INFO - downloader - skip downloading file 000029.jpg
# 2025-06-06 13:06:21,559 - INFO - downloader - skip downloading file 000030.jpg
# 2025-06-06 13:06:21,677 - INFO - downloader - image #31	https://www.southernliving.com/thmb/gfVu5djoNeIOK0qqqdDg5VAYvNw=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/CroissantBreadPudding_Audit_2241_Steps_8_271-9559578fece643cb836bc41c28417041.jpg
# 2025-06-06 13:06:21,678 - INFO - downloader - skip downloading file 000032.jpg
# 2025-06-06 13:06:21,679 - INFO - downloader - skip downloading file 000033.jpg
# 2025-06-06 13:06:22,017 - INFO - downloader - image #34	https://i0.wp.com/gluesticksblog.com/wp-content/uploads/2021/03/croissant-bread.png
# 2025-06-06 13:06:24,146 - INFO - downloader - image #35	https://www.gillsbakesandcakes.com/wp-content/uploads/2024/07/IMG_0500-scaled.jpg
# 2025-06-06 13:06:24,148 - INFO - downloader - skip downloading file 000036.jpg
# 2025-06-06 13:06:24,941 - INFO - downloader - image #37	https://wildgrain.com/cdn/shop/files/Wildgrain_Croissant_Loaf_143352787.PORTRAIT.ORIGINAL.png
# 2025-06-06 13:06:24,945 - INFO - downloader - skip downloading file 000038.jpg
# 2025-06-06 13:06:24,945 - INFO - downloader - skip downloading file 000039.jpg
# 2025-06-06 13:06:25,597 - INFO - downloader - image #40	https://myriadrecipes.com/wp-content/uploads/2025/03/viral-croissant-bread-2.png
# 2025-06-06 13:06:25,602 - INFO - downloader - skip downloading file 000041.jpg
# 2025-06-06 13:06:25,603 - INFO - downloader - skip downloading file 000042.jpg
# 2025-06-06 13:06:25,604 - INFO - downloader - skip downloading file 000043.jpg
# 2025-06-06 13:06:26,047 - INFO - downloader - image #44	https://cdn.urbanpiper.com/media/bizmedia/2022/06/08/Croissant.png
# 2025-06-06 13:06:26,278 - INFO - downloader - image #45	https://sallysbakingaddiction.com/wp-content/uploads/2022/03/croissant-bread-loaf-3.jpg
# 2025-06-06 13:06:26,279 - INFO - downloader - skip downloading file 000046.jpg
# 2025-06-06 13:06:26,280 - INFO - downloader - skip downloading file 000047.jpg
# 2025-06-06 13:06:26,281 - INFO - downloader - skip downloading file 000048.jpg
# 2025-06-06 13:06:26,282 - INFO - downloader - skip downloading file 000049.jpg
# 2025-06-06 13:06:26,283 - INFO - downloader - skip downloading file 000050.jpg
# 2025-06-06 13:06:26,283 - INFO - downloader - skip downloading file 000051.jpg
# 2025-06-06 13:06:26,284 - INFO - downloader - skip downloading file 000052.jpg
# 2025-06-06 13:06:26,284 - INFO - downloader - skip downloading file 000053.jpg
# 2025-06-06 13:06:26,285 - INFO - downloader - skip downloading file 000054.jpg
# 2025-06-06 13:06:26,286 - INFO - downloader - skip downloading file 000055.jpg
# 2025-06-06 13:06:26,286 - INFO - downloader - skip downloading file 000056.jpg
# 2025-06-06 13:06:26,287 - INFO - downloader - skip downloading file 000057.jpg
# 2025-06-06 13:06:26,288 - INFO - downloader - skip downloading file 000058.jpg
# 2025-06-06 13:06:26,288 - INFO - downloader - skip downloading file 000059.jpg
# 2025-06-06 13:06:26,289 - INFO - downloader - skip downloading file 000060.jpg
# 2025-06-06 13:06:26,291 - INFO - downloader - skip downloading file 000061.jpg
# 2025-06-06 13:06:26,294 - INFO - downloader - skip downloading file 000062.jpg
# 2025-06-06 13:06:26,295 - INFO - downloader - skip downloading file 000063.jpg
# 2025-06-06 13:06:26,296 - INFO - downloader - skip downloading file 000064.jpg
# 2025-06-06 13:06:26,296 - INFO - downloader - skip downloading file 000065.jpg
# 2025-06-06 13:06:26,297 - INFO - downloader - skip downloading file 000066.jpg
# 2025-06-06 13:06:26,299 - INFO - downloader - skip downloading file 000067.jpg
# 2025-06-06 13:06:26,400 - INFO - downloader - image #68	https://sarahsvegankitchen.com/wp-content/uploads/2024/05/Vegan-Croissants-1.jpg
# 2025-06-06 13:06:26,783 - INFO - downloader - image #69	https://www.melskitchencafe.com/wp-content/uploads/2023/03/choc-croissant-bread11.jpg
# 2025-06-06 13:06:27,558 - INFO - downloader - image #70	https://i0.wp.com/twosistersbakery.bcitwebdeveloper.ca/wp-content/uploads/2021/02/croissant-loaf.jpg
# 2025-06-06 13:06:31,125 - INFO - downloader - image #71	https://images.immediate.co.uk/production/volatile/sites/2/2019/04/OLI_EAST_47_quickfix-05a017c.jpg
# 2025-06-06 13:06:31,265 - INFO - downloader - image #72	https://amybakesbread.com/wp-content/uploads/2025/02/DSC_2783.jpg
# 2025-06-06 13:06:32,116 - INFO - downloader - image #73	https://bevcooks.com/wp-content/uploads/2019/04/1F7207CB-FE92-4123-8333-C59EAA231C72.jpg
# 2025-06-06 13:06:32,330 - INFO - downloader - image #74	https://assets.surlatable.com/m/14251c5a28c3fccb/72_dpi_webp-REC_163039_Classic_Croissants.jpg
# 2025-06-06 13:06:32,472 - INFO - downloader - image #75	https://media-cldnry.s-nbcnews.com/image/upload/t_social_share_1200x630_center,f_auto,q_auto:best/newscms/2019_19/1435659/siri-daly-croissant-bread-pudding-today-main-190510.jpg
# 2025-06-06 13:06:32,675 - INFO - downloader - image #76	https://www.inspiredtaste.net/wp-content/uploads/2011/11/Nutella-Bread-Pudding-Recipe-1-1200.jpg
# 2025-06-06 13:06:34,138 - INFO - downloader - image #77	https://www.hormelfoods.com/wp-content/uploads/culinary_collective_croissants-Recipe-2400x1000-1.jpg
# 2025-06-06 13:06:34,665 - INFO - downloader - image #78	https://therecipecritic.com/wp-content/uploads/2024/06/crossaint-bread-1200x1799.jpg
# 2025-06-06 13:06:34,902 - INFO - downloader - image #79	https://www.unicornsinthekitchen.com/wp-content/uploads/2018/10/Croissant-Bread-Pudding-SQ.jpg
# 2025-06-06 13:06:35,938 - INFO - downloader - image #80	https://i0.wp.com/sourdoughbrandon.com/wp-content/uploads/2023/01/Hand-holding-a-sourdough-croissant-with-honeycomb-crumb.jpg
# 2025-06-06 13:06:36,020 - INFO - downloader - image #81	https://wildgrain.com/cdn/shop/products/IMG_9806.jpg
# 2025-06-06 13:06:36,413 - INFO - downloader - image #82	https://tarateaspoon.com/wp-content/uploads/2024/01/chocolate-croissant-bread-pudding-14-low-res-sq.jpg
# 2025-06-06 13:06:37,418 - INFO - downloader - image #83	https://d14iv1hjmfkv57.cloudfront.net/assets/recipes/croissant-bread-pudding/_600x600_crop_center-center_61_line/Page-192-horizon-web.jpg
# 2025-06-06 13:06:37,642 - INFO - parser - parsing result page https://www.google.com/search?q=croissant+bread&ijn=1&start=100&tbs=&tbm=isch
# Exception in thread parser-001:
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/threading.py", line 1041, in _bootstrap_inner
#     self.run()
#     ~~~~~~~~^^
#   File "/Users/hong/Desktop/25-1/AI intro/AI project/Image-Crawler/.venv/lib/python3.13/site-packages/ipykernel/ipkernel.py", line 766, in run_closure
#     _threading_Thread_run(self)
#     ~~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "/opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/threading.py", line 992, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/hong/Desktop/25-1/AI intro/AI project/Image-Crawler/.venv/lib/python3.13/site-packages/icrawler/parser.py", line 93, in worker_exec
#     for task in self.parse(response, **kwargs):
#                 ~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
# 2025-06-06 13:06:39,172 - INFO - downloader - image #84	https://assets.zuckerjagdwurst.com/u4q97pkqszcdxj62j8adg1z9xdpz/1110/701/55/true/center/R870-Vegane-Schoko-Croissants-01.jpg
# 2025-06-06 13:06:41,077 - INFO - downloader - image #85	https://www.tasteofhome.com/wp-content/uploads/2024/08/Croissant-Bread-Pudding_TOHD24_97140_JuliaHartbeck_3.jpg
# 2025-06-06 13:06:41,233 - INFO - downloader - image #86	https://theobroma.in/cdn/shop/files/Croissant01.jpg
# 2025-06-06 13:06:46,241 - INFO - downloader - no more download task for thread downloader-001
# 2025-06-06 13:06:46,242 - INFO - downloader - thread downloader-001 exit
# 2025-06-06 13:06:46,837 - INFO - icrawler.crawler - Crawling task done!
# ✅ Finished 'croissant' - Total images now: 132
#
# 🎉 All crawling completed successfully.

# %%
import os
import hashlib

def hash_file(filepath):
    try:
        with open(filepath, "rb") as f:
            return hashlib.md5(f.read()).hexdigest()
    except Exception as e:
        print(f"Error reading {filepath}: {e}")
        return None

def get_image_files(folder):
    return [
        os.path.join(folder, f)
        for f in os.listdir(folder)
        if f.lower().endswith(('.jpg', '.jpeg', '.png', '.webp', '.gif')) and os.path.isfile(os.path.join(folder, f))
    ]

def remove_duplicates(folder1, folder2):
    print(f"Scanning folder1: {folder1}")
    print(f"Scanning folder2: {folder2}")
    
    hashes_folder1 = {}
    for f in get_image_files(folder1):
        h = hash_file(f)
        if h:
            hashes_folder1[h] = f

    removed = 0
    for f in get_image_files(folder2):
        h = hash_file(f)
        if h in hashes_folder1:
            print(f"🗑️ Removing duplicate: {f}")
            os.remove(f)
            removed += 1

    print(f"\n✅ Done. {removed} duplicate files removed from '{folder2}'.")

# 사용 예시
folder_path1 = "/Users/hong/Desktop/25-1/AI intro/AI project/Image-Crawler/v2/raw_images_crawled/cookie"
folder_path2 = "/Users/hong/Desktop/25-1/AI intro/AI project/Image-Crawler/v2/raw_images_crawled/chuross/images"

remove_duplicates(folder_path1, folder_path2)
# Out:
# Scanning folder1: /Users/hong/Desktop/25-1/AI intro/AI project/Image-Crawler/v2/raw_images_crawled/chuross
# Scanning folder2: /Users/hong/Desktop/25-1/AI intro/AI project/Image-Crawler/v2/raw_images_crawled/churros/images
#
# ✅ Done. 0 duplicate files removed from '/Users/hong/Desktop/25-1/AI intro/AI project/Image-Crawler/v2/raw_images_crawled/churros/images'.

# %%
import os
import cv2
import numpy as np
import hashlib
from glob import glob
from tqdm import tqdm

# ----------- 중복 제거 함수들 -----------

def hash_file(filepath):
    try:
        with open(filepath, "rb") as f:
            return hashlib.md5(f.read()).hexdigest()
    except Exception as e:
        print(f"❌ Error reading {filepath}: {e}")
        return None

def mse(imageA, imageB):
    # 이미지 크기 맞추기
    if imageA.shape != imageB.shape:
        imageB = cv2.resize(imageB, (imageA.shape[1], imageA.shape[0]))
    err = np.sum((imageA.astype("float") - imageB.astype("float")) ** 2)
    err /= float(imageA.shape[0] * imageA.shape[1])
    return err

def get_image_files(folder):
    return [
        os.path.join(folder, f)
        for f in os.listdir(folder)
        if f.lower().endswith(('.jpg', '.jpeg', '.png', '.webp', '.gif')) and os.path.isfile(os.path.join(folder, f))
    ]

def remove_internal_duplicates(folder, mse_threshold=50.0):
    print(f"🔍 Removing duplicates in: {folder}")
    
    files = get_image_files(folder)
    hashes = {}
    removed = 0

    for path in tqdm(files, desc="MD5 duplicate check"):
        h = hash_file(path)
        if not h:
            continue

        if h in hashes:
            os.remove(path)
            removed += 1
        else:
            hashes[h] = path

    # 이미지 유사도 기반 중복 제거 (비슷하지만 해시 다른 경우)
    files = get_image_files(folder)
    images = [(f, cv2.imread(f)) for f in files]
    kept = []

    for i in range(len(images)):
        keep = True
        path_i, img_i = images[i]
        if img_i is None:
            continue

        for j in range(i):
            path_j, img_j = images[j]
            if img_j is None:
                continue

            error = mse(img_i, img_j)
            if error < mse_threshold:
                print(f"🗑️ Removing visually duplicate: {path_i} ≈ {path_j} (MSE={error:.2f})")
                os.remove(path_i)
                removed += 1
                keep = False
                break

        if keep:
            kept.append(images[i])

    print(f"✅ {removed} duplicates removed in '{folder}'.")


# ----------- 전처리 함수들 -----------

def is_blurry(image, threshold=100.0):
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    return cv2.Laplacian(gray, cv2.CV_64F).var() < threshold

def is_too_dark_or_bright(image, dark_threshold=30, bright_threshold=220):
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    mean_brightness = np.mean(gray)
    return mean_brightness < dark_threshold or mean_brightness > bright_threshold

def has_sufficient_content(image, min_std=15):
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    return np.std(gray) > min_std

def process_image(input_path, output_path, target_size=(640, 640)):
    try:
        image = cv2.imread(input_path)
        if image is None:
            return False

        h, w = image.shape[:2]
        if h < 300 or w < 300 or h < target_size[0]*0.75 or w < target_size[1]*0.75:
            return False

        if is_blurry(image) or is_too_dark_or_bright(image) or not has_sufficient_content(image):
            return False

        scale = min(target_size[0]/w, target_size[1]/h)
        new_w, new_h = int(w * scale), int(h * scale)
        resized = cv2.resize(image, (new_w, new_h), interpolation=cv2.INTER_AREA)

        canvas = np.full((target_size[1], target_size[0], 3), 114, dtype=np.uint8)
        x_offset = (target_size[0] - new_w) // 2
        y_offset = (target_size[1] - new_h) // 2
        canvas[y_offset:y_offset+new_h, x_offset:x_offset+new_w] = resized

        cv2.imwrite(output_path, canvas)
        return True
    except Exception as e:
        print(f"❌ Error processing {os.path.basename(input_path)}: {e}")
        return False

def preprocess_category_images(bread_name, image_dir, target_size=(640, 640)):
    print(f"\n📦 Preprocessing images for: {bread_name}")
    
    remove_internal_duplicates(image_dir)

    image_paths = sorted(glob(os.path.join(image_dir, "*.jpg")))
    if not image_paths:
        print(f"⚠️ No images found for {bread_name}")
        return 0

    processed_dir = os.path.join(os.path.dirname(image_dir), "processed")
    os.makedirs(processed_dir, exist_ok=True)

    success = 0
    for idx, input_path in enumerate(tqdm(image_paths, desc=f"Processing {bread_name}")):
        output_filename = f"{idx:04d}.jpg"
        output_path = os.path.join(processed_dir, output_filename)

        if process_image(input_path, output_path, target_size):
            success += 1
        else:
            if os.path.exists(output_path):
                os.remove(output_path)

    print(f"✅ {bread_name}: {success} images successfully processed.\n")
    return success


# ----------- 실행 -----------

# 기본 설정
base_dir = "/Users/hong/Desktop/25-1/AI intro/AI project/Image-Crawler/v2/raw_images_crawled"
bread_types = sorted([name for name in os.listdir(base_dir) if os.path.isdir(os.path.join(base_dir, name))])

total_processed = 0

for bread in bread_types:
    image_dir = os.path.join(base_dir, bread, "images")
    if os.path.exists(image_dir):
        count = preprocess_category_images(bread, image_dir)
        total_processed += count
    else:
        print(f"⚠️ Directory not found: {image_dir}")

print(f"\n🎉 All preprocessing completed. Total images: {total_processed}")
# Out:
# 📦 Preprocessing images for: croissant
# 🔍 Removing duplicates in: /Users/hong/Desktop/25-1/AI intro/AI project/Image-Crawler/v2/raw_images_crawled/croissant/images
# MD5 duplicate check: 100%|██████████| 196/196 [00:00<00:00, 1070.91it/s]
# 🗑️ Removing visually duplicate: /Users/hong/Desktop/25-1/AI intro/AI project/Image-Crawler/v2/raw_images_crawled/croissant/images/000010.jpg ≈ /Users/hong/Desktop/25-1/AI intro/AI project/Image-Crawler/v2/raw_images_crawled/croissant/images/ 00013.jpg (MSE=2.41)
# ✅ 15 duplicates removed in '/Users/hong/Desktop/25-1/AI intro/AI project/Image-Crawler/v2/raw_images_crawled/croissant/images'.
# Processing croissant: 100%|██████████| 172/172 [00:02<00:00, 75.77it/s]
# ✅ croissant: 130 images successfully processed.
#
#
# 🎉 All preprocessing completed. Total images: 130
